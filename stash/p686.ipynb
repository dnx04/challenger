# %% [markdown]
# # Project Euler - 686

# %%
from sage.functions.log import logb

# %%
def p686(n):
    l, r = logb(1.23, 10), logb(1.24, 10)
    j, cnt = 0, 0
    while cnt < n:
        if l < j * log(2, 10) - int(j * log(2, 10)) < r:
            cnt += 1
        if cnt == n:
            break
        j += 1
    return j

# %%
p686(45)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_511/4103231614.py in <module>
# ----> 1 p686(Integer(45))
#
# /tmp/ipykernel_511/4073313932.py in p686(n)
#      10             j += Integer(1)
#      11             cnt += Integer(1)
# ---> 12         elif test(j + Integer(196)):
#      13             j += Integer(196)
#      14             cnt += Integer(1)
#
# /usr/lib/python3/dist-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.__nonzero__ (build/cythonized/sage/symbolic/expression.cpp:48510)()
#    3488                 if pynac_result == relational_notimplemented and self.operator()==operator.ne:
#    3489                     return not (self.lhs()-self.rhs()).is_trivial_zero()
# -> 3490                 res = self.test_relation()
#    3491                 if res in (True, False):
#    3492                     return res
#
# ...
