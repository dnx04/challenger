# %% [markdown]
# # [Project Euler 146 - Investigating a Prime Pattern](https://projecteuler.net/problem=146)

# %%
save = {}

def chk_prime(n):
    if n in save:
        return save[n]
    save[n] = is_prime(n)
    return save[n]

def p146(n):
    ans = 0
    for i in range(10, n, 10):
        if all(chk == True for chk in [chk_prime(i^2 + j) for j in [1, 3, 7, 9, 13, 27]]):
            ans += i
            print(i)
    return ans

# %%
p146(3 * 10^6)
# Out:
# 10
# 315410
# 927070
# 2525870
# 3768360
